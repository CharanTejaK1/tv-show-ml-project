# %% [markdown]
# # TV Show & Movie Genre Prediction
# ## Objective
# The objective of this project is to develop machine learning models to predict the genre of TV shows and movies using the provided dataset.
#
# This notebook focuses on:
# - Data Understanding
# - Exploratory Data Analysis (EDA)
# - Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.metrics import confusion_matrix
# %load_ext autoreload
# %autoreload 2
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading
#
# In this step, the dataset is loaded using a reusable function defined in `data_loader.py`.
#
# Using reusable functions ensures modular and maintainable code.

# %%
import sys
import os

sys.path.append(os.path.abspath(r"C:\Users\hemab\Downloads\tv-show-ml-project\src"))

# %%
import visualization
import preprocess
import train
import evaluate
import feature_engineering
import data_loader
import data_split

# %%
df = data_loader.load_data(r"C:\Users\hemab\Downloads\tv-show-ml-project\data\tv-shows.csv")

df.head()
# Out:
#    id     type                                             title  \
# 0   1    Movie  ChuChuTV Surprise Eggs Learning Videos (English)
# 1   2    Movie                    The Journey Is the Destination
# 2   3  TV Show                                         Champions
# 3   4  TV Show                                      The Returned
# 4   5    Movie                        Super Bheem Bana Vajraveer
#
#          director                                               cast  \
# 0             NaN                                                NaN
# 1  Bronwen Hughes  Ben Schnetzer, Kelly Macdonald, Sam Hazeldine,...
# 2             NaN  Anders Holm, Fortune Feimster, Andy Favreau, J...
# 3             NaN  Anne Cosigny, Frédéric Pierrot, Clotilde Hesme...
# 4       Sumit Das  Sonal Kaushal, Rupa Bhimani, Julie Tejwani, Sa...
#
#          country         date_added  release_year rating  duration  \
# 0            NaN   October 18, 2019          2019   TV-Y    61 min
# 1  United States   November 7, 2017          2016      R   123 min
# 2  United States      June 19, 2021          2018  TV-14  1 Season
# 3         France  February 17, 2019          2015  TV-MA  1 Season
# 4          India      June 18, 2019          2018  TV-Y7    63 min
#
#                                       listed_in  \
# 0                      Children & Family Movies
# 1                                        Dramas
# 2                                   TV Comedies
# 3  International TV Shows, TV Dramas, TV Horror
# 4                      Children & Family Movies
#
#                                          description platform
# 0  From colors and letters to animals of all kind...  Netflix
# 1  Spirited 22-year-old activist and photojournal...  Netflix
# 2  Years after getting his girlfriend pregnant, w...  Netflix
# 3  On returning home and finding they're believed...  Netflix
# 4  Hoping to find a magical root, a monster has c...  Netflix

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# EDA helps in understanding the structure of the dataset, identifying missing values, and analyzing feature distributions.

# %% [markdown]
# ## Dataset Shape
#
# This step checks the number of rows and columns in the dataset to understand its size.

# %%
df.shape
# Out:
# (9338, 13)

# %% [markdown]
# ### Column Names
#
# List all columns available in the dataset.

# %%
df.columns
# Out:
# Index(['id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'platform'],
#       dtype='object')

# %% [markdown]
# ## Data Types and Missing Values
#
# This step checks column data types and identifies missing values in each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9338 entries, 0 to 9337
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            9338 non-null   int64
#  1   type          9338 non-null   object
#  2   title         9338 non-null   object
#  3   director      6483 non-null   object
#  4   cast          8400 non-null   object
#  5   country       8376 non-null   object
#  6   date_added    9325 non-null   object
#  7   release_year  9338 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9335 non-null   object
#  10  listed_in     9338 non-null   object
#  11  description   9338 non-null   object
#  12  platform      9338 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 948.5+ KB

# %%
visualization.plot_missing_percentage(df)

# %% [markdown]
# ## Missing Values Analysis
#
# This step counts missing values in each column to understand data completeness.

# %%
df = preprocess.handle_missing_values(df)
df.isnull().sum()
# Out:
# id              0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# platform        0
# dtype: int64

# %% [markdown]
# ## Dropping Unnecessary Columns
#
# Some columns such as 'id' and 'title' do not contribute to predicting the genre.
# Removing such columns helps improve model performance and reduces noise.

# %%
df = feature_engineering.drop_unnecessary_columns(df)
df.columns
# Out:
# Index(['type', 'director', 'cast', 'country', 'date_added', 'release_year',
#        'rating', 'duration', 'listed_in', 'description', 'platform'],
#       dtype='object')

# %%
df=feature_engineering.consolidate_genres(df)
print(f"Classes after consolidation: {df['listed_in'].nunique()}")
print(df['listed_in'].value_counts())
# Out:
# Classes after consolidation: 12
# listed_in
# Comedies                    1615
# Dramas                      1514
# Action & Adventure          1224
# Documentaries               1009
# International TV Shows       925
# Children & Family Movies     888
# Animation                    501
# Crime & Thriller TV          377
# Thrillers                    303
# TV Comedies                  214
# Animals & Nature             172
# International Movies         114
# Name: count, dtype: int64

# %%
df['clean_desc'] = df['description'].apply(feature_engineering.clean_text)

# %%
df = feature_engineering.combine_text_features(df)
df[['combined_text']].head()
# Out:
#                                        combined_text
# 0  movie tv-y united states from colors and lette...
# 1  movie r united states spirited year old activi...
# 2  tv show tv-14 united states years after gettin...
# 3  tv show tv-ma france on returning home and fin...
# 4  movie tv-y7 india hoping to find a magical roo...

# %%
df.head()
# Out:
#       type        director                                               cast  \
# 0    Movie     Jack Hannah                                 David Attenborough
# 1    Movie  Bronwen Hughes  Ben Schnetzer, Kelly Macdonald, Sam Hazeldine,...
# 2  TV Show     Jack Hannah  Anders Holm, Fortune Feimster, Andy Favreau, J...
# 3  TV Show     Jack Hannah  Anne Cosigny, Frédéric Pierrot, Clotilde Hesme...
# 4    Movie       Sumit Das  Sonal Kaushal, Rupa Bhimani, Julie Tejwani, Sa...
#
#          country         date_added  release_year rating  duration  \
# 0  United States   October 18, 2019          2019   TV-Y    61 min
# 1  United States   November 7, 2017          2016      R   123 min
# 2  United States      June 19, 2021          2018  TV-14  1 Season
# 3         France  February 17, 2019          2015  TV-MA  1 Season
# 4          India      June 18, 2019          2018  TV-Y7    63 min
#
#                   listed_in  \
# 0  Children & Family Movies
# 1                    Dramas
# 2               TV Comedies
# 3    International TV Shows
# 4  Children & Family Movies
#
#                                          description platform  \
# 0  From colors and letters to animals of all kind...  Netflix
# 1  Spirited 22-year-old activist and photojournal...  Netflix
# 2  Years after getting his girlfriend pregnant, w...  Netflix
# 3  On returning home and finding they're believed...  Netflix
# 4  Hoping to find a magical root, a monster has c...  Netflix
#
#                                           clean_desc  \
# 0  from colors and letters to animals of all kind...
# 1  spirited year old activist and photojournalist...
# 2  years after getting his girlfriend pregnant wa...
# 3  on returning home and finding they re believed...
# 4  hoping to find a magical root a monster has ca...
#
#                                        combined_text
# 0  movie tv-y united states from colors and lette...
# 1  movie r united states spirited year old activi...
# 2  tv show tv-14 united states years after gettin...
# 3  tv show tv-ma france on returning home and fin...
# 4  movie tv-y7 india hoping to find a magical roo...

# %% [markdown]
# ## Exploratory Data Visualization
#
# Visualizations help understand the structure and distribution of the dataset.
# This step includes plotting genre distribution, content type distribution, release year trends, and missing value patterns.

# %%
visualization.plot_genre_distribution(df)

# %%
visualization.plot_type_distribution(df)

# %%
visualization.plot_release_year_distribution(df)

# %%
visualization.plot_rating_distribution(df)

# %%
visualization.plot_platform_distribution(df)

# %% [markdown]
# ## Target Variable Selection
#
# The column 'listed_in' represents the genre of the TV show or movie.
# This will be used as the target variable for prediction.

# %% [markdown]
# ## Splitting Features and Target
#
# The dataset is divided into input features (X) and target variable (y).

# %%
X, y = feature_engineering.split_features_target(df)

print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (8856, 12)
# Target Shape: (8856,)

# %% [markdown]
# ## Text Vectorization using TF-IDF
#
# Text data is converted into numerical form using TF-IDF vectorization.
# This allows machine learning models to process textual information.

# %%
x_tfidf, tfidf, ohe = feature_engineering.apply_tfidf(df)
print('Feature matrix shape:', x_tfidf.shape)
# Out:
# Feature matrix shape: (8856, 21188)

# %% [markdown]
# ## Train-Test Split
#
# The dataset is divided into training and testing sets.
# This helps evaluate model performance on unseen data.

# %%
X_train, X_test, y_train, y_test = data_split.split_data(
    x_tfidf,
    y
)
print(X_train.shape)
print(X_test.shape)
# Out:
# (7084, 21188)
# (1772, 21188)

# %% [markdown]
# ## Model Training
#
# Two machine learning models were selected for this task:
#
# 1. Logistic Regression — suitable for high-dimensional sparse data
# 2. Random Forest — capable of capturing complex relationships and providing feature importance

# %%
lr_model = train.train_logistic_regression(X_train,y_train)

svm_model = train.train_svm(X_train,y_train)

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

# ── UPGRADE 6: Wider GridSearch param range ───────────────────────────────
param_grid = {'C': [0.5, 1, 2, 3]}

svm_gs = LinearSVC(class_weight='balanced', max_iter=10000)
grid_svm = GridSearchCV(svm_gs, param_grid, cv=3, scoring='f1_weighted', verbose=1)
grid_svm.fit(X_train, y_train)
best_svm = grid_svm.best_estimator_

print('Best Parameters:', grid_svm.best_params_)
print('Best CV F1:', round(grid_svm.best_score_, 4))
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best Parameters: {'C': 1}
# Best CV F1: 0.6065

# %% [markdown]
# ## Model Evaluation
#
# In this step, both models are evaluated using standard classification metrics such as accuracy, precision, recall, and F1-score.
#
# These metrics help compare model performance and determine the best-performing model.

# %%
lr_results = evaluate.evaluate_model(lr_model,X_test,y_test)

print("Logistic Regression Results:")
print("Accuracy:", lr_results["accuracy"])
print("F1 Score:", lr_results["f1_score"])
# Out:
# Logistic Regression Results:
# Accuracy: 0.6162528216704289
# F1 Score: 0.6147152384590999

# %%
svm_results = evaluate.evaluate_model(best_svm,X_test,y_test)

print("Linear SVM Results:")
print("Accuracy:", svm_results["accuracy"])
print("F1 Score:", svm_results["f1_score"])
# Out:
# Linear SVM Results:
# Accuracy: 0.6230248306997742
# F1 Score: 0.6192971057567311

# %% [markdown]
# ## Model Comparison
#
# The performance of Logistic Regression and Random Forest models is compared based on evaluation metrics.

# %%
comparison = pd.DataFrame({
    "Model": ["Logistic Regression", "Linear SVM"],
    "Accuracy": [
        lr_results["accuracy"],
        svm_results["accuracy"]
    ],
    "F1 Score": [
        lr_results["f1_score"],
        svm_results["f1_score"]
    ]
})

comparison
# Out:
#                  Model  Accuracy  F1 Score
# 0  Logistic Regression  0.616253  0.614715
# 1           Linear SVM  0.623025  0.619297

# %% [markdown]
# ## Confusion Matrix Visualization
#
# Confusion matrices help visualize how well the model predicts each class.

# %%
top_genres = y_test.value_counts().nlargest(10).index

mask = y_test.isin(top_genres)

y_test_top = y_test[mask]
y_pred_top = y_test[mask]


cm = confusion_matrix(y_test_top, y_pred_top, labels=top_genres)

plt.figure(figsize=(10,8))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=top_genres,
    yticklabels=top_genres
)

plt.title("Confusion Matrix (Top 10 Genres)")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
y_pred = svm_model.predict(X_test)

results_df = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

results_df.head(20)
# Out:
#                       Actual                 Predicted
# 0              Documentaries                  Comedies
# 1                     Dramas        Action & Adventure
# 2           Animals & Nature  Children & Family Movies
# 3           Animals & Nature          Animals & Nature
# 4                TV Comedies    International TV Shows
# 5              Documentaries             Documentaries
# 6              Documentaries             Documentaries
# 7                     Dramas        Action & Adventure
# 8                     Dramas                  Comedies
# 9         Action & Adventure                    Dramas
# 10  Children & Family Movies  Children & Family Movies
# 11    International TV Shows    International TV Shows
# 12                 Animation    International TV Shows
# 13        Action & Adventure                    Dramas
# 14                    Dramas                  Comedies
# 15                    Dramas                    Dramas
# 16                 Animation        Action & Adventure
# 17                  Comedies                  Comedies
# 18             Documentaries             Documentaries
# 19                    Dramas                 Thrillers

# %%
wrong_predictions = results_df[
    results_df["Actual"] != results_df["Predicted"]
]

wrong_predictions.head(20)
# Out:
#                     Actual                 Predicted
# 0            Documentaries                  Comedies
# 1                   Dramas        Action & Adventure
# 2         Animals & Nature  Children & Family Movies
# 4              TV Comedies    International TV Shows
# 7                   Dramas        Action & Adventure
# 8                   Dramas                  Comedies
# 9       Action & Adventure                    Dramas
# 12               Animation    International TV Shows
# 13      Action & Adventure                    Dramas
# 14                  Dramas                  Comedies
# 16               Animation        Action & Adventure
# 19                  Dramas                 Thrillers
# 26                  Dramas             Documentaries
# 27                Comedies                    Dramas
# 28  International TV Shows             Documentaries
# 29             TV Comedies       Crime & Thriller TV
# 30               Thrillers                  Comedies
# 34                  Dramas                 Animation
# 35    International Movies                    Dramas
# 36           Documentaries        Action & Adventure

# %%
feature_names = tfidf.get_feature_names_out()

top_features = np.argsort(
    svm_model.coef_[0]
)[-20:]

important_words = [
    feature_names[i]
    for i in top_features
]

print("Top Important Words:")
print(important_words)
# Out:
# Top Important Words:
# ['alice', 'racer', 'sword', 'tv y7', 'y7', 'tv tv', 'agent', 'fighter', 'hell', 'revenge', 'action', 'protect', 'spider', 'tv tv united', 'soldiers', 'hunter', 'officer', 'terrorist', 'cia', 'tv tv y7']

# %%
plt.figure(figsize=(10,6))

plt.barh(
    important_words,
    svm_model.coef_[0][top_features]
)

plt.title("Top Important Features")

plt.xlabel("Importance")

plt.show()
